# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.31.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-151209
# aml-quickstarts-151209
# southcentralus
# 3d1a56d2-7c81-4118-9790-f85d1acf0c77

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-151209)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "udacity-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

# compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [a4526aa1][613c7316-9633-4fc3-bb09-c701af839d9d], (This step will run and generate new outputs)
# Submitted PipelineRun b7382d39-1b58-4b7f-a681-9a55e30ea832
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/b7382d39-1b58-4b7f-a681-9a55e30ea832?wsid=/subscriptions/3d1a56d2-7c81-4118-9790-f85d1acf0c77/resourcegroups/aml-quickstarts-151209/workspaces/quick-starts-ws-151209&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: b7382d39-1b58-4b7f-a681-9a55e30ea832
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/b7382d39-1b58-4b7f-a681-9a55e30ea832?wsid=/subscriptions/3d1a56d2-7c81-4118-9790-f85d1acf0c77/resourcegroups/aml-quickstarts-151209/workspaces/quick-starts-ws-151209&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: a62664da-59af-4404-bba7-906c9e54abc3
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a62664da-59af-4404-bba7-906c9e54abc3?wsid=/subscriptions/3d1a56d2-7c81-4118-9790-f85d1acf0c77/resourcegroups/aml-quickstarts-151209/workspaces/quick-starts-ws-151209&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'a62664da-59af-4404-bba7-906c9e54abc3', 'target': 'udacity-cluster', 'status': 'Completed', 'startTimeUtc': '2021-07-15T19:51:54.465493Z', 'endTimeUtc': '2021-07-15T20:28:26.830621Z', 'properties': {'ContentSnapshotId': '5d0daedc-7979-4160-ace4-27327e8316a9', 'StepType': 'AutoMLStep', 'azureml.moduleid': '613c7316-9633-4fc3-bb09-c701af839d9d', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'a4526aa1', 'azureml.pipelinerunid': 'b7382d39-1b58-4b7f-a681-9a55e30ea832', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'udacity-cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "3d1a56d2-7c81-4118-9790-f85d1acf0c77", "resource_group": "aml-quickstarts-151209", "workspace_name": "quick-starts-ws-151209", "region": "southcentralus", "compute_target": "udacity-cluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["MultinomialNaiveBayes", "LogisticRegression", "KNN", "LinearSVM", "LightGBM", "RandomForest", "DecisionTree", "GradientBoosting", "ExtremeRandomTrees", "TensorFlowLinearClassifier", "XGBoostClassifier", "TensorFlowDNN", "SGD", "BernoulliNaiveBayes", "SVM", "AveragedPerceptronClassifier"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"b4077268-6afa-4cbd-ab65-5f30e0f1fa04\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '5d0daedc-7979-4160-ace4-27327e8316a9', 'SetupRunId': 'a62664da-59af-4404-bba7-906c9e54abc3_setup', 'SetupRunContainerId': 'dcid.a62664da-59af-4404-bba7-906c9e54abc3_setup', 'Cl ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'b7382d39-1b58-4b7f-a681-9a55e30ea832', 'status': 'Completed', 'startTimeUtc': '2021-07-15T19:51:35.764621Z', 'endTimeUtc': '2021-07-15T20:29:21.251355Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.b7382d39-1b58-4b7f-a681-9a55e30ea832/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=mPcF8nyhDDC%2FVMzQ0t10pLN%2FIJLTXJj5%2BYMyYoKY6TU%3D&st=2021-07-15T19%3A41%3A39Z&se=2021-07-16T03%3A51%3A39Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.b7382d39-1b58-4b7f-a681-9a55e30ea832/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=DvmTxYzJSTEYgGI3iXTi5ZKRcj%2FVyTB7SYuftQCyjCc%3D&st=2021-07-15T19%3A41%3A39Z&se=2021-07-16T03%3A51%3A39Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.b7382d39-1b58-4b7f-a681-9a55e30ea832/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=o5pBvyuvvABKZcURJ9zkBzUDCSr%2BwqPgdZ2VaVTgDoQ%3D&st=2021-07-15T19%3A41%3A39Z&se=2021-07-16T03%3A51%3A39Z&sp=r'}, 'submittedBy': 'ODL_User 151209'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a62664da-59af-4404-bba7-906c9e54abc3/metrics_data
# Downloaded azureml/a62664da-59af-4404-bba7-906c9e54abc3/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  a62664da-59af-4404-bba7-906c9e54abc3_4  \
# AUC_macro                                          [0.8877297641739232]
# precision_score_weighted                            [0.788565560086672]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                    [0.926863881535649]
# f1_score_weighted                                  [0.8353395018439429]
# AUC_micro                                          [0.9651289372549109]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_macro                      [0.7283676762039686]
# AUC_weighted                                       [0.8877297641739232]
# recall_score_macro                                                [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# balanced_accuracy                                                 [0.5]
# log_loss                                           [0.2731575778099937]
# matthews_correlation                                              [0.0]
# average_precision_score_micro                      [0.9662436126063945]
# recall_score_weighted                              [0.8880121396054628]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_3  \
# AUC_macro                                          [0.9098415847453075]
# precision_score_weighted                           [0.9097202981667287]
# f1_score_macro                                      [0.699009647271631]
# accuracy                                           [0.8160849772382398]
# recall_score_micro                                 [0.8160849772382398]
# precision_score_macro                              [0.6712486690689735]
# average_precision_score_weighted                   [0.9381543513523057]
# f1_score_weighted                                   [0.844684400908915]
# AUC_micro                                          [0.8949768467881396]
# precision_score_micro                              [0.8160849772382398]
# norm_macro_recall                                  [0.6697416119752448]
# f1_score_micro                                     [0.8160849772382398]
# average_precision_score_macro                      [0.7652308890826969]
# AUC_weighted                                       [0.9098415847453074]
# recall_score_macro                                 [0.8348708059876224]
# weighted_accuracy                                  [0.8114209641078377]
# balanced_accuracy                                  [0.8348708059876224]
# log_loss                                           [0.4861440179408065]
# matthews_correlation                               [0.4789412483193937]
# average_precision_score_micro                      [0.8823533365279052]
# recall_score_weighted                              [0.8160849772382398]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_8  \
# AUC_macro                                          [0.8786642326436934]
# precision_score_weighted                            [0.788565560086672]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                   [0.9267279078472471]
# f1_score_weighted                                  [0.8353395018439429]
# AUC_micro                                          [0.9633258650505088]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_macro                      [0.7393011461717998]
# AUC_weighted                                       [0.8786642326436934]
# recall_score_macro                                                [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# balanced_accuracy                                                 [0.5]
# log_loss                                          [0.27633603602218604]
# matthews_correlation                                              [0.0]
# average_precision_score_micro                      [0.9628720466080699]
# recall_score_weighted                              [0.8880121396054628]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_7  \
# AUC_macro                                          [0.8451626108878998]
# precision_score_weighted                            [0.788565560086672]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                    [0.916086681588035]
# f1_score_weighted                                  [0.8353395018439429]
# AUC_micro                                          [0.9566626216666168]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_macro                      [0.7108221537445376]
# AUC_weighted                                       [0.8451626108878998]
# recall_score_macro                                                [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# balanced_accuracy                                                 [0.5]
# log_loss                                          [0.27867344456240506]
# matthews_correlation                                              [0.0]
# average_precision_score_micro                      [0.9562006250293776]
# recall_score_weighted                              [0.8880121396054628]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_9  \
# AUC_macro                                          [0.8103916480039715]
# precision_score_weighted                           [0.8782266055405251]
# f1_score_macro                                     [0.6027872168284789]
# accuracy                                           [0.7286798179059181]
# recall_score_micro                                 [0.7286798179059181]
# precision_score_macro                              [0.6058682465792072]
# average_precision_score_weighted                   [0.9068968515389648]
# f1_score_weighted                                    [0.77632219308455]
# AUC_micro                                          [0.8077941240809522]
# precision_score_micro                              [0.7286798179059181]
# norm_macro_recall                                 [0.46711012564671117]
# f1_score_micro                                     [0.7286798179059181]
# average_precision_score_macro                      [0.7080265628253858]
# AUC_weighted                                       [0.8103916480039715]
# recall_score_macro                                 [0.7335550628233556]
# weighted_accuracy                                   [0.727469426466062]
# balanced_accuracy                                  [0.7335550628233556]
# log_loss                                            [0.565203855883367]
# matthews_correlation                               [0.3144904766812835]
# average_precision_score_micro                      [0.7732177152737381]
# recall_score_weighted                              [0.7286798179059181]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_0  \
# AUC_macro                                          [0.9450464668693166]
# precision_score_weighted                           [0.9072720074188747]
# f1_score_macro                                     [0.7653697272147331]
# accuracy                                           [0.9116843702579667]
# recall_score_micro                                 [0.9116843702579667]
# precision_score_macro                              [0.7819118765348991]
# average_precision_score_weighted                   [0.9531771295804466]
# f1_score_weighted                                  [0.9091539479147899]
# AUC_micro                                           [0.979695082216353]
# precision_score_micro                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_micro                                     [0.9116843702579667]
# average_precision_score_macro                      [0.8151093723721079]
# AUC_weighted                                       [0.9450464668693167]
# recall_score_macro                                 [0.7513392683482543]
# weighted_accuracy                                  [0.9514937218005303]
# balanced_accuracy                                  [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# matthews_correlation                               [0.5323740218566827]
# average_precision_score_micro                      [0.9806603102489483]
# recall_score_weighted                              [0.9116843702579667]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_11  \
# AUC_macro                                           [0.8929423521849709]
# precision_score_weighted                            [0.9072367600497868]
# f1_score_macro                                      [0.6359360213505113]
# accuracy                                            [0.7405159332321699]
# recall_score_micro                                  [0.7405159332321699]
# precision_score_macro                                [0.637764475490592]
# average_precision_score_weighted                    [0.9320063371306668]
# f1_score_weighted                                   [0.7873577850432639]
# AUC_micro                                            [0.861125860905727]
# precision_score_micro                               [0.7405159332321699]
# norm_macro_recall                                   [0.6320077725725992]
# f1_score_micro                                      [0.7405159332321699]
# average_precision_score_macro                       [0.7473194044728511]
# AUC_weighted                                        [0.8929423521849708]
# recall_score_macro                                  [0.8160038862862996]
# weighted_accuracy                                   [0.7217743164034094]
# balanced_accuracy                                   [0.8160038862862996]
# log_loss                                           [0.48514731359187224]
# matthews_correlation                               [0.41729658348575405]
# average_precision_score_micro                       [0.8713182472004264]
# recall_score_weighted                               [0.7405159332321699]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_2  \
# AUC_macro                                          [0.8867419843029599]
# precision_score_weighted                            [0.902713216598306]
# f1_score_macro                                     [0.4948333486646429]
# accuracy                                           [0.8907435508345979]
# recall_score_micro                                 [0.8907435508345979]
# precision_score_macro                              [0.9452221545952526]
# average_precision_score_weighted                   [0.9296908294766095]
# f1_score_weighted                                  [0.8418825042863689]
# AUC_micro                                          [0.9649482247669137]
# precision_score_micro                              [0.8907435508345979]
# norm_macro_recall                                [0.024390243902439046]
# f1_score_micro                                     [0.8907435508345979]
# average_precision_score_macro                      [0.7459589670026461]
# AUC_weighted                                         [0.88674198430296]
# recall_score_macro                                 [0.5121951219512195]
# weighted_accuracy                                  [0.9847268861645987]
# balanced_accuracy                                  [0.5121951219512195]
# log_loss                                           [0.2524741562193548]
# matthews_correlation                               [0.1473708040376222]
# average_precision_score_micro                      [0.9650824618856663]
# recall_score_weighted                              [0.8907435508345979]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_6  \
# AUC_macro                                          [0.8843598278771577]
# precision_score_weighted                           [0.8835314759207953]
# f1_score_macro                                     [0.6208856905947701]
# accuracy                                           [0.9001517450682853]
# recall_score_micro                                 [0.9001517450682853]
# precision_score_macro                                [0.80512182977664]
# average_precision_score_weighted                   [0.9282790286006717]
# f1_score_weighted                                  [0.8733903940207878]
# AUC_micro                                          [0.9648479210465114]
# precision_score_micro                              [0.9001517450682853]
# norm_macro_recall                                 [0.17708072842861022]
# f1_score_micro                                     [0.9001517450682853]
# average_precision_score_macro                      [0.7377778605614607]
# AUC_weighted                                       [0.8843598278771578]
# recall_score_macro                                 [0.5885403642143051]
# weighted_accuracy                                  [0.9775164219890989]
# balanced_accuracy                                  [0.5885403642143051]
# log_loss                                           [0.2539699230013688]
# matthews_correlation                              [0.32872844682600216]
# average_precision_score_micro                      [0.9656645790229028]
# recall_score_weighted                              [0.9001517450682853]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_17  ...  \
# AUC_macro                                            [0.813108621516837]  ...
# precision_score_weighted                            [0.8783417459337245]  ...
# f1_score_macro                                      [0.6053444224390889]  ...
# accuracy                                            [0.7323216995447648]  ...
# recall_score_micro                                  [0.7323216995447648]  ...
# precision_score_macro                               [0.6069949010088918]  ...
# average_precision_score_weighted                    [0.9064758217103159]  ...
# f1_score_weighted                                   [0.7790634687522044]  ...
# AUC_micro                                           [0.8237549420766739]  ...
# precision_score_micro                               [0.7323216995447648]  ...
# norm_macro_recall                                  [0.46884302404199696]  ...
# f1_score_micro                                      [0.7323216995447648]  ...
# average_precision_score_macro                       [0.7005255582531826]  ...
# AUC_weighted                                        [0.8131086215168372]  ...
# recall_score_macro                                  [0.7344215120209985]  ...
# weighted_accuracy                                   [0.7318003729058824]  ...
# balanced_accuracy                                   [0.7344215120209985]  ...
# log_loss                                            [0.5677213821322001]  ...
# matthews_correlation                                [0.3167453644367441]  ...
# average_precision_score_micro                       [0.7908814532757684]  ...
# recall_score_weighted                               [0.7323216995447648]  ...
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_32  \
# AUC_macro                                           [0.9279911715726863]
# precision_score_weighted                            [0.8998313721264986]
# f1_score_macro                                      [0.7480159067348708]
# accuracy                                            [0.9016691957511381]
# recall_score_micro                                  [0.9016691957511381]
# precision_score_macro                               [0.7529777781201433]
# average_precision_score_weighted                    [0.9438412687574508]
# f1_score_weighted                                   [0.9007137147467618]
# AUC_micro                                           [0.9750166366937535]
# precision_score_micro                               [0.9016691957511381]
# norm_macro_recall                                   [0.4866638140065611]
# f1_score_micro                                       [0.901669195751138]
# average_precision_score_macro                        [0.783708984908271]
# AUC_weighted                                        [0.9279911715726863]
# recall_score_macro                                  [0.7433319070032806]
# weighted_accuracy                                   [0.9409800615960403]
# balanced_accuracy                                   [0.7433319070032806]
# log_loss                                           [0.19895208143082388]
# matthews_correlation                               [0.49621594161988497]
# average_precision_score_micro                       [0.9753812927648012]
# recall_score_weighted                               [0.9016691957511381]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_18  \
# AUC_macro                                           [0.8613333963141409]
# precision_score_weighted                            [0.8780213731533512]
# f1_score_macro                                      [0.5936599749468067]
# accuracy                                            [0.7153262518968133]
# recall_score_micro                                  [0.7153262518968133]
# precision_score_macro                                [0.602151727892763]
# average_precision_score_weighted                    [0.9220403997228319]
# f1_score_weighted                                   [0.7662061037106265]
# AUC_micro                                           [0.8359549692480215]
# precision_score_micro                               [0.7153262518968133]
# norm_macro_recall                                   [0.4615455860641995]
# f1_score_micro                                      [0.7153262518968133]
# average_precision_score_macro                        [0.719750473100821]
# AUC_weighted                                        [0.8613333963141409]
# recall_score_macro                                  [0.7307727930320997]
# weighted_accuracy                                   [0.7114912935547897]
# balanced_accuracy                                   [0.7307727930320997]
# log_loss                                            [0.5653615297454023]
# matthews_correlation                               [0.30707549273016205]
# average_precision_score_micro                        [0.831341394406551]
# recall_score_weighted                               [0.7153262518968133]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_37  \
# AUC_macro                                           [0.9445963393331813]
# precision_score_weighted                            [0.9120095177008954]
# f1_score_macro                                      [0.7778684426785059]
# accuracy                                            [0.9153262518968134]
# recall_score_micro                                  [0.9153262518968134]
# precision_score_macro                               [0.7908539557157215]
# average_precision_score_weighted                    [0.9511850724987102]
# f1_score_weighted                                   [0.9134701472198686]
# AUC_micro                                           [0.9790895756434198]
# precision_score_micro                               [0.9153262518968134]
# norm_macro_recall                                   [0.5328305982991477]
# f1_score_micro                                      [0.9153262518968134]
# average_precision_score_macro                       [0.8065630889185048]
# AUC_weighted                                        [0.9445963393331813]
# recall_score_macro                                  [0.7664152991495738]
# weighted_accuracy                                   [0.9522968134908367]
# balanced_accuracy                                   [0.7664152991495738]
# log_loss                                           [0.18433642615201254]
# matthews_correlation                                [0.5567331268061596]
# average_precision_score_micro                       [0.9800502053116099]
# recall_score_weighted                               [0.9153262518968134]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_34  \
# AUC_macro                                           [0.9466395108243633]
# precision_score_weighted                            [0.9094405060333096]
# f1_score_macro                                      [0.7707217299094236]
# accuracy                                            [0.9138088012139606]
# recall_score_micro                                  [0.9138088012139606]
# precision_score_macro                               [0.7880303888928242]
# average_precision_score_weighted                    [0.9534479562096919]
# f1_score_weighted                                   [0.9112801783634001]
# AUC_micro                                           [0.9799783089750644]
# precision_score_micro                               [0.9138088012139606]
# norm_macro_recall                                   [0.5121756719959545]
# f1_score_micro                                      [0.9138088012139606]
# average_precision_score_macro                       [0.8156444474627804]
# AUC_weighted                                        [0.9466395108243632]
# recall_score_macro                                  [0.7560878359979772]
# weighted_accuracy                                    [0.952966650597168]
# balanced_accuracy                                   [0.7560878359979772]
# log_loss                                            [0.1786148688542624]
# matthews_correlation                                [0.5431798191877868]
# average_precision_score_micro                       [0.9809090890567123]
# recall_score_weighted                               [0.9138088012139606]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_36  \
# AUC_macro                                           [0.9458763316272945]
# precision_score_weighted                            [0.9083837833780429]
# f1_score_macro                                      [0.7680037996089013]
# accuracy                                            [0.9128983308042489]
# recall_score_micro                                  [0.9128983308042489]
# precision_score_macro                               [0.7855784879651856]
# average_precision_score_weighted                    [0.9539031024254765]
# f1_score_weighted                                   [0.9102831069309071]
# AUC_micro                                           [0.9798781894671884]
# precision_score_micro                               [0.9128983308042489]
# norm_macro_recall                                   [0.5064138542957541]
# f1_score_micro                                      [0.9128983308042489]
# average_precision_score_macro                       [0.8182311086415686]
# AUC_weighted                                        [0.9458763316272946]
# recall_score_macro                                  [0.7532069271478771]
# weighted_accuracy                                   [0.9525453867527467]
# balanced_accuracy                                   [0.7532069271478771]
# log_loss                                           [0.18007865410300244]
# matthews_correlation                                [0.5378120541497806]
# average_precision_score_micro                       [0.9807852964155305]
# recall_score_weighted                               [0.9128983308042489]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_41  \
# AUC_macro                                           [0.9436970104492569]
# precision_score_weighted                            [0.9103936567676629]
# f1_score_macro                                      [0.7727908552875257]
# accuracy                                            [0.9150227617602428]
# recall_score_micro                                  [0.9150227617602428]
# precision_score_macro                               [0.7920274421073921]
# average_precision_score_weighted                    [0.9529012007897981]
# f1_score_weighted                                    [0.912294877094483]
# AUC_micro                                           [0.9792477220969833]
# precision_score_micro                               [0.9150227617602428]
# norm_macro_recall                                   [0.5135427259945873]
# f1_score_micro                                      [0.9150227617602428]
# average_precision_score_macro                       [0.8146358499907052]
# AUC_weighted                                         [0.943697010449257]
# recall_score_macro                                  [0.7567713629972936]
# weighted_accuracy                                   [0.9543123034451771]
# balanced_accuracy                                   [0.7567713629972936]
# log_loss                                           [0.18212320288728928]
# matthews_correlation                                [0.5476651690313282]
# average_precision_score_micro                       [0.9802204735535665]
# recall_score_weighted                               [0.9150227617602428]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_43  \
# AUC_macro                                           [0.9463227544100459]
# precision_score_weighted                            [0.9112858568424094]
# f1_score_macro                                      [0.7749361894045931]
# accuracy                                            [0.9159332321699545]
# recall_score_micro                                  [0.9159332321699545]
# precision_score_macro                               [0.7947825361313043]
# average_precision_score_weighted                    [0.9540769305581739]
# f1_score_weighted                                   [0.9131760047232391]
# AUC_micro                                           [0.9799944275710886]
# precision_score_micro                               [0.9159332321699545]
# norm_macro_recall                                   [0.5169362800941748]
# f1_score_micro                                      [0.9159332321699545]
# average_precision_score_macro                       [0.8186176268448488]
# AUC_weighted                                         [0.946322754410046]
# recall_score_macro                                  [0.7584681400470874]
# weighted_accuracy                                   [0.9550275551853912]
# balanced_accuracy                                   [0.7584681400470874]
# log_loss                                           [0.17788346285927492]
# matthews_correlation                                [0.5520575833451492]
# average_precision_score_micro                       [0.9809272175719745]
# recall_score_weighted                               [0.9159332321699545]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_52  \
# AUC_macro                                            [0.948076955137289]
# precision_score_weighted                            [0.9025422018486526]
# f1_score_macro                                      [0.7431023789309716]
# accuracy                                            [0.9122913505311078]
# recall_score_micro                                  [0.9122913505311078]
# precision_score_macro                               [0.7960098378271234]
# average_precision_score_weighted                    [0.9556032772125219]
# f1_score_weighted                                   [0.9048885421252679]
# AUC_micro                                           [0.9805104068563901]
# precision_score_micro                               [0.9122913505311078]
# norm_macro_recall                                  [0.42047283767437804]
# f1_score_micro                                      [0.9122913505311078]
# average_precision_score_macro                       [0.8246530723956665]
# AUC_weighted                                         [0.948076955137289]
# recall_score_macro                                   [0.710236418837189]
# weighted_accuracy                                   [0.9624561245772847]
# balanced_accuracy                                    [0.710236418837189]
# log_loss                                            [0.2013818752834865]
# matthews_correlation                               [0.49892704174198266]
# average_precision_score_micro                       [0.9814156412941052]
# recall_score_weighted                               [0.9122913505311078]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_53  \
# AUC_macro                                           [0.9452687520723464]
# precision_score_weighted                            [0.9050785502090379]
# f1_score_macro                                      [0.7563648625864104]
# accuracy                                            [0.9122913505311078]
# recall_score_micro                                  [0.9122913505311078]
# precision_score_macro                               [0.7883498766423777]
# average_precision_score_weighted                    [0.9540396021990124]
# f1_score_weighted                                   [0.9076182881078789]
# AUC_micro                                           [0.9798586629394332]
# precision_score_micro                               [0.9122913505311078]
# norm_macro_recall                                   [0.4654698460860205]
# f1_score_micro                                      [0.9122913505311078]
# average_precision_score_macro                       [0.8189137794272798]
# AUC_weighted                                        [0.9452687520723464]
# recall_score_macro                                  [0.7327349230430102]
# weighted_accuracy                                   [0.9568703545572205]
# balanced_accuracy                                   [0.7327349230430102]
# log_loss                                           [0.20153313410098375]
# matthews_correlation                                [0.5181084301565659]
# average_precision_score_micro                       [0.9808082885753788]
# recall_score_weighted                               [0.9122913505311078]
#
#                                  a62664da-59af-4404-bba7-906c9e54abc3_39
# AUC_macro                                           [0.9454160160193537]
# precision_score_weighted                            [0.9078455714866506]
# f1_score_macro                                      [0.7654131134837717]
# accuracy                                              [0.91350531107739]
# recall_score_micro                                    [0.91350531107739]
# precision_score_macro                               [0.7892229966217245]
# average_precision_score_weighted                     [0.953579804067766]
# f1_score_weighted                                   [0.9100547289333064]
# AUC_micro                                            [0.979779635765783]
# precision_score_micro                                 [0.91350531107739]
# norm_macro_recall                                  [0.49288779969139407]
# f1_score_micro                                        [0.91350531107739]
# average_precision_score_macro                       [0.8168232718023524]
# AUC_weighted                                        [0.9454160160193535]
# recall_score_macro                                   [0.746443899845697]
# weighted_accuracy                                   [0.9549821405515084]
# balanced_accuracy                                    [0.746443899845697]
# log_loss                                           [0.17884045029542522]
# matthews_correlation                                [0.5339559652724806]
# average_precision_score_micro                       [0.9807268804681095]
# recall_score_weighted                                 [0.91350531107739]
#
# [21 rows x 54 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a62664da-59af-4404-bba7-906c9e54abc3/model_data
# Downloaded azureml/a62664da-59af-4404-bba7-906c9e54abc3/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=None, reg_alpha=0.9473684210526315, reg_lambda=0.42105263157894735, subsample=0.99))], verbose=False))], flatten_transform=None, weights=[0.07142857142857142, 0.07142857142857142, 0.35714285714285715, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142, 0.14285714285714285, 0.14285714285714285]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('34', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.3, gamma=5, max_depth=10, max_leaves=7, n_estimators=600, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0, reg_lambda=1.0416666666666667, subsample=0.9, tree_method='auto'))],
#                verbose=False)), ('43', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.4, gamma=0, max_depth=9, max_leaves=15, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=2.5, reg_lambda=2.5, subsample=0.9, tree_method='auto'))],
#                verbose=False)), ('36', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.7, eta=0.01, gamma=0, grow_policy='lossguide', max_bin=255, max_depth=6, max_leaves=0, n_estimators=400, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           d...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.6666666666666667, reg_lambda=0, subsample=0.7, tree_method='hist'))],
#                verbose=False)), ('39', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.2, gamma=0, max_depth=7, max_leaves=3, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=1...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.7291666666666667, reg_lambda=0.7291666666666667, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('0', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsamplin...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('31', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.9, eta=0.001, gamma=5, max_depth=6, max_leaves=15, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_featu...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.875, reg_lambda=1.9791666666666667, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('51', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.8, eta=0.3, gamma=1, max_depth=10, max_leaves=7, n_estimators=10, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0, reg_lambda=0.5208333333333334, subsample=1, tree_method='auto'))],
#                verbose=False)), ('35', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=True
#       )),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='gbdt', colsample_bytree=0.8911111111111111, learning_rate=0.010535263157894737, max_bin=200, max_depth=5, min_child_weight=3, min_data_in_leaf=1e-05, min_split_gain=0.7894736842105263,...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.9473684210526315, reg_lambda=0.42105263157894735, subsample=0.99))],
#                verbose=False))],
#       weights=[0.07142857142857142, 0.07142857142857142, 0.35714285714285715, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142, 0.14285714285714285, 0.14285714285714285],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row0_col0" class="data row0 col0" >29028</td>
#                         <td id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row0_col1" class="data row0 col1" >230</td>
#             </tr>
#             <tr>
#                         <th id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row1_col0" class="data row1 col0" >1289</td>
#                         <td id="T_7a4b7c44_e5ab_11eb_b316_b5253b81c0d1row1_col1" class="data row1 col1" >2403</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: b1d47c0a-62d2-4374-9ef3-1a6971fad394,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/3d1a56d2-7c81-4118-9790-f85d1acf0c77/resourceGroups/aml-quickstarts-151209/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-151209/PipelineRuns/PipelineSubmit/b1d47c0a-62d2-4374-9ef3-1a6971fad394)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  ca4c815a-a194-4d4c-a899-f8bab35cd731

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
published_pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: ca4c815a-a194-4d4c-a899-f8bab35cd731
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ca4c815a-a194-4d4c-a899-f8bab35cd731?wsid=/subscriptions/3d1a56d2-7c81-4118-9790-f85d1acf0c77/resourcegroups/aml-quickstarts-151209/workspaces/quick-starts-ws-151209&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ca4c815a-a194-4d4c-a899-f8bab35cd731', 'status': 'Completed', 'startTimeUtc': '2021-07-15T20:30:24.372462Z', 'endTimeUtc': '2021-07-15T20:30:27.772142Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'b1d47c0a-62d2-4374-9ef3-1a6971fad394'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.ca4c815a-a194-4d4c-a899-f8bab35cd731/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=MNmf8pIY%2FsTElgq1SvVS9NGaKUqAx5Psb15awBK2xPY%3D&st=2021-07-15T20%3A20%3A45Z&se=2021-07-16T04%3A30%3A45Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.ca4c815a-a194-4d4c-a899-f8bab35cd731/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=I2BNRyjBrsRJZftdl%2BYbbbrLyN6Rege6aKxwkcs22xo%3D&st=2021-07-15T20%3A20%3A45Z&se=2021-07-16T04%3A30%3A45Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg151209.blob.core.windows.net/azureml/ExperimentRun/dcid.ca4c815a-a194-4d4c-a899-f8bab35cd731/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=xgrKlJjN59rghymHwz6WyadYfcNjlikmU2Acs%2FIV5CI%3D&st=2021-07-15T20%3A20%3A45Z&se=2021-07-16T04%3A30%3A45Z&sp=r'}, 'submittedBy': 'ODL_User 151209'}
# 'Finished'
